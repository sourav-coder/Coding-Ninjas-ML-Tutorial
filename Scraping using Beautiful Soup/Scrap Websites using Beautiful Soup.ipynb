# %%
import requests as req
from bs4 import BeautifulSoup

# %%
# 1

r=req.get("https://www.imdb.com/search/title/?release_date=2018&sort=num_votes,desc&page=1&ref_=adv_nxt")
data=BeautifulSoup(r.text)
li=data.find_all(class_='lister-item-content')
for i in range(3):
    print(li[i].a.string,li[i].p.find(class_='genre').string)
# Out:
# Avengers: Infinity War
# Action, Adventure, Sci-Fi
# Black Panther
# Action, Adventure, Sci-Fi
# Deadpool 2
# Action, Adventure, Comedy

# %%
# 2

for i in range(5):
    r=req.get(f"https://www.imdb.com/search/title/?release_date=201{i}&sort=num_votes,desc&page=1&ref_=adv_nxt")
    data=BeautifulSoup(r.text)
    print(r.status_code)
    li=data.find_all(class_='lister-item-content')
    for i in li:
        print(i.a.string)
# Out:
# 200
# Inception
# Shutter Island
# The Walking Dead
# Sherlock
# Toy Story 3
# Iron Man 2
# Black Swan
# How to Train Your Dragon
# The Social Network
# The King's Speech
# Kick-Ass
# Despicable Me
# Harry Potter and the Deathly Hallows: Part 1
# Tangled
# Scott Pilgrim vs. the World
# Alice in Wonderland
# Easy A
# The Town
# 127 Hours
# The Fighter
# The Expendables
# Due Date
# True Grit
# Tron
# Salt
# The Book of Eli
# RED
# Insidious
# Prince of Persia: The Sands of Time
# Clash of the Titans
# Robin Hood
# The Other Guys
# The A-Team
# Megamind
# Grown Ups
# The Twilight Saga: Eclipse
# The Tourist
# Spartacus: Blood and Sand
# Predators
# Shrek Forever After
# Machete
# Love & Other Drugs
# The Next Three Days
# Unstoppable
# Blue Valentine
# Knight and Day
# Downton Abbey
# Percy Jackson & the Olympians: The Lightning Thief
# Boardwalk Empire
# Get Him to the Greek
# 200
# Game of Thrones
# Harry Potter and the Deathly Hallows: Part 2
# The Intouchables
# Thor
# ...

# %%
# 3

r=req.get("https://www.imdb.com/search/title/?release_date=2018&sort=num_votes,desc&page=1&ref_=adv_nxt")
data=BeautifulSoup(r.text)
li=data.find_all(class_='lister-item-content')
d={}
for i in li:
    votes=i.find_all(class_='sort-num_votes-visible')
    for j in votes:
        s=j.find_all('span')[1]['data-value']
        break
    d[i.a.string]=int(s)

d={i:j for i,j in sorted(d.items(),reverse=True,key=lambda x:x[1])}

s=''
m=-9999
for i in li:
#     print(i.a.string)
    ch=int(i.p.find(class_='runtime').string.split()[0])
#     print(ch)
    if ch>m:
        m=ch
        s=i.a.string
print(s,m)
print(f"{s} with {d[s]} votes")
# Out:
# The Haunting of Hill House 572
# The Haunting of Hill House with 212819 votes

# %%
# 4

r=req.get("https://en.wikipedia.org/wiki/Applications_of_artificial_intelligence")
data=BeautifulSoup(r.text)

li=data.find_all('span',{'class':'mw-headline'})
for i in li:
    print(i.string)
# Out:
# Internet and e-commerce
# Search engines
# Recommendation systems
# Targeted advertising and increasing internet engagement
# Virtual assistants
# Spam filtering
# Automatic translation
# Facial recognition and image labeling
# Games
# Chess
# Jeopardy!
# Go
# Poker
# Video games
# General game playing
# Economic and social challenges
# Agriculture
# Cybersecurity
# Education
# Finance
# Trading and investment
# Underwriting
# Audit
# History
# Government
# Military
# None
# Healthcare
# Workplace health and safety
# Biochemistry
# Law
# Legal analysis
# Law enforcement and legal proceedings
# Service sector
# Human resources and recruiting
# Job search
# Online and telephone customer service
# Hospitality
# Media
# Deepfakes
# Music
# Writing and reporting
# Video games
# Art
# Utilities
# Manufacturing
# Sensors
# Toys and games
# Transportation
# Automotive
# Aviation
# Maritime
# Computer science
# Programming assistance
# Historical contributions
# List of applications
# ...

# %%
# 5


r=req.get("https://en.wikipedia.org/wiki/Artificial_intelligence")
data=BeautifulSoup(r.text)
m=-1
img=0
li=data.find_all('img')
for i in li:
    s=int(i['height'])*int(i['width'])
    if s>m:
        m=s
        img=i['src']
print(img,m)
# Out:
# //upload.wikimedia.org/wikipedia/commons/6/69/EM_Clustering_of_Old_Faithful_data.gif 111240

# %%
# 6

r=req.get('http://quotes.toscrape.com/')
data=BeautifulSoup(r.text)

li=data.find_all(class_='quote')
for i in li:
    a_tags=i.div
    tags=a_tags.find_all(class_='tag')
    for j in tags:
        if "humor"==j.string:
            print(i.span.string)
# Out:
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “A day without sunshine is like, you know, night.”

# %%
# 7

r=req.get('http://quotes.toscrape.com/')
data=BeautifulSoup(r.text)

li=data.find_all(class_='author')
s=set()
for i in li:
    s.add(i.string)
sorted(s)
# Out:
# ['Albert Einstein',
#  'André Gide',
#  'Eleanor Roosevelt',
#  'J.K. Rowling',
#  'Jane Austen',
#  'Marilyn Monroe',
#  'Steve Martin',
#  'Thomas A. Edison']

# %%
# 8
url="http://quotes.toscrape.com/"
r=req.get(url)
data=BeautifulSoup(r.text)

d={}
quotes=data.find_all(class_='quote')
for i in quotes:
    author=i.find_all('span')
    name=author[1].small.string
#     print(name)
    if name[0].lower()=='j':
        rq=req.get(url+author[1].a['href'])
        dt=BeautifulSoup(rq.text)
        dob=dt.find(class_='author-born-date').string
        d[name]=dob

d={i:j for i,j in sorted(d.items(),key=lambda x:x[0])}
print(d)
# Out:
# {'J.K. Rowling': 'July 31, 1965', 'Jane Austen': 'December 16, 1775'}

# %%
# 9

print("Quotes of albert Einstein: \n")

for i in range(1,11):
    url=f"https://quotes.toscrape.com/page/{i}/"
    r=req.get(url)
    data=BeautifulSoup(r.text)
    quotes=data.find_all(class_='quote')
    for i in quotes:
        author=i.find_all('span')
        name=author[1].small.string
        if name=="Albert Einstein":
                print(author[0].string)
# Out:
# Quotes of albert Einstein:
#
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “Try not to become a man of success. Rather become a man of value.”
# “If you can't explain it to a six year old, you don't understand it yourself.”
# “If you want your children to be intelligent, read them fairy tales. If you want them to be more intelligent, read them more fairy tales.”
# “Logic will get you from A to Z; imagination will get you everywhere.”
# “Any fool can know. The point is to understand.”
# “Life is like riding a bicycle. To keep your balance, you must keep moving.”
# “If I were not a physicist, I would probably be a musician. I often think in music. I live my daydreams in music. I see my life in terms of music.”
# “Anyone who has never made a mistake has never tried anything new.”
